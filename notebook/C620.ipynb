# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/C620.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
#!pip install autorch

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c620_col_names.pkl')
c620_df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/c620/cleaned/c620_train.csv',index_col=0).dropna(axis=0)
print(c620_df.shape)
c620_df.head(3)
# Out:
# (15552, 420)
#          Combined Feed to Tatoray Stripper C620_Flow Rate_Volume Flow Rate_m3/hr  ...  Density_Bottoms Production Rate and Composition
# 001-001                                              178.0                        ...                                         0.871859
# 001-002                                              178.0                        ...                                         0.871859
# 001-003                                              178.0                        ...                                         0.871859
#
# [3 rows x 420 columns]

# %%
x_col = c['case']+c['x41']
op_col = c['density']+c['yRefluxRate']+c['yHeatDuty']+c['yControl']
sp_col = c['vent_gas_sf'] +c['distillate_sf'] +c['sidedraw_sf'] +c['bottoms_sf']
wt_col = c['vent_gas_x'] +c['distillate_x'] +c['sidedraw_x'] +c['bottoms_x']
y_col = sp_col + op_col
n_idx = [ [i,i+41,i+41*2,i+41*3]for i in range(41)]
for idx in n_idx:
  assert np.allclose(c620_df[y_col].iloc[:,idx].sum(axis=1),1.0) # check
print(len(x_col),len(y_col))
# Out:
# 43 174

# %%
from autorch.utils import PartBulider
c620 = PartBulider(c620_df,x_col,y_col,normalize_idx_list=n_idx)
c620.train()
# Out:
#   0%|          | 1/300 [00:01<06:20,  1.27s/it]
# epoch:0 train_loss:0.0117 valid_loss:0.0028
#  17%|█▋        | 51/300 [00:57<04:33,  1.10s/it]
# epoch:50 train_loss:0.0010 valid_loss:0.0010
#  34%|███▎      | 101/300 [01:54<03:54,  1.18s/it]
# epoch:100 train_loss:0.0010 valid_loss:0.0010
#  50%|█████     | 151/300 [02:55<03:02,  1.22s/it]
# epoch:150 train_loss:0.0010 valid_loss:0.0010
#  67%|██████▋   | 201/300 [03:59<02:10,  1.32s/it]
# epoch:200 train_loss:0.0010 valid_loss:0.0010
#  84%|████████▎ | 251/300 [05:10<01:19,  1.63s/it]
# epoch:250 train_loss:0.0010 valid_loss:0.0010
# 100%|██████████| 300/300 [06:27<00:00,  1.29s/it]

# %%
c620.test(e=0.01)
# Out:
#                                                           R2  ...       MAPE
# Tatoray Stripper C620 Split Factors Calculation...         0  ...  0.0298835
# Tatoray Stripper C620 Split Factors Calculation...  0.995384  ...   0.021826
# Tatoray Stripper C620 Split Factors Calculation...  0.994661  ...   0.090484
# Tatoray Stripper C620 Split Factors Calculation...  0.993918  ...   0.298419
# Tatoray Stripper C620 Split Factors Calculation...  0.993969  ...   0.917554
# ...                                                      ...  ...        ...
# Tatoray Stripper C620 Operation_Heat Duty_Conde...  0.998059  ...   0.299671
# Tatoray Stripper C620 Operation_Heat Duty_Reboi...  0.998918  ...   0.238047
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999193  ...  0.0154462
# Tatoray Stripper C620 Operation_Column Temp Pro...   0.99869  ...  0.0128014
# AVG                                                 0.765157  ...    1.11547
#
# [175 rows x 3 columns]

# %%
from autorch.function import sp2wt

x_test = c620.data['X_test']
x41 = x_test[c['x41']].values
sp = c620.predict(x_test).iloc[:,:41*4]
s1,s2,s3,s4 = sp.iloc[:,:41].values,sp.iloc[:,41:41*2].values,sp.iloc[:,41*2:41*3].values,sp.iloc[:,41*3:41*4].values
w1,w2,w3,w4 = sp2wt(x41,s1),sp2wt(x41,s2),sp2wt(x41,s3),sp2wt(x41,s4)
wt_pred = np.hstack((w1,w2,w3,w4))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=wt_col)
wt_pred.head(3)
# Out:
#          Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 078-007                                                0.0                                      ...                                                0.0
# 029-039                                                0.0                                      ...                                                0.0
# 125-057                                                0.0                                      ...                                                0.0
#
# [3 rows x 164 columns]

# %%
wt_real = c620_df.loc[x_test.index,wt_col]
wt_real.head(3)
# Out:
#          Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 078-007                                                0.0                                      ...                                                0.0
# 029-039                                                0.0                                      ...                                                0.0
# 125-057                                                0.0                                      ...                                                0.0
#
# [3 rows x 164 columns]

# %%
c620.show_metrics(wt_real,wt_pred,e=0.01).fillna(0)
# Out:
#                                                           R2  ...      MAPE
# Tatoray Stripper C620 Operation_Vent Gas Produc...  1.000000  ...  0.000000
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.948337  ...  1.197867
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.902556  ...  1.149921
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.504281  ...  0.992649
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.991857  ...  0.810137
# ...                                                      ...  ...       ...
# Tatoray Stripper C620 Operation_Bottoms Product...  0.999994  ...  0.027423
# Tatoray Stripper C620 Operation_Bottoms Product...  0.999994  ...  0.027423
# Tatoray Stripper C620 Operation_Bottoms Product...  1.000000  ...  0.000000
# Tatoray Stripper C620 Operation_Bottoms Product...  1.000000  ...  0.000000
# AVG                                                 0.894077  ...  2.219218
#
# [165 rows x 3 columns]

# %%
c620.shrink() # 節省空間

# %%
joblib.dump(c620,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620.pkl']
