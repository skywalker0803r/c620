# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/C620.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
#!pip install autorch

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c620_col_names.pkl')
c620_df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/c620/cleaned/c620_train.csv',index_col=0).dropna(axis=0)
print(c620_df.shape)
c620_df.head(3)
# Out:
# (15552, 381)
#          Combined Feed to Tatoray Stripper C620_Detailed Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Split Factors Calculation_Split Factor for Individual Component to Tatoray Stripper C620 Bottoms_Oxygen_Fraction
# 001-001                                                0.0                         ...                                                0.0
# 001-002                                                0.0                         ...                                                0.0
# 001-003                                                0.0                         ...                                                0.0
#
# [3 rows x 381 columns]

# %%
x_col = c['case']+c['x41']
op_col = c['density']+c['yRefluxRate']+c['yHeatDuty']+c['yControl']
sp_col = c['vent_gas_sf'] +c['distillate_sf'] +c['sidedraw_sf'] +c['bottoms_sf']
wt_col = c['vent_gas_x'] +c['distillate_x'] +c['sidedraw_x'] +c['bottoms_x']
y_col = sp_col + op_col
n_idx = [ [i,i+41,i+41*2,i+41*3]for i in range(41)]
for idx in n_idx:
  assert np.allclose(c620_df[y_col].iloc[:,idx].sum(axis=1),1.0) # check
print(len(x_col),len(y_col))
# Out:
# 44 173

# %%
from autorch.utils import PartBulider
c620 = PartBulider(c620_df,x_col,y_col,normalize_idx_list=n_idx)
c620.train()
# Out:
#   0%|          | 1/300 [00:00<03:27,  1.44it/s]
# epoch:0 train_loss:0.0111 valid_loss:0.0025
#  17%|█▋        | 51/300 [00:46<03:44,  1.11it/s]
# epoch:50 train_loss:0.0002 valid_loss:0.0002
#  34%|███▎      | 101/300 [01:31<03:00,  1.10it/s]
# epoch:100 train_loss:0.0002 valid_loss:0.0002
#  50%|█████     | 151/300 [02:18<02:26,  1.02it/s]
# epoch:150 train_loss:0.0002 valid_loss:0.0002
#  67%|██████▋   | 201/300 [03:07<01:37,  1.02it/s]
# epoch:200 train_loss:0.0002 valid_loss:0.0002
#  84%|████████▎ | 251/300 [03:57<00:50,  1.04s/it]
# epoch:250 train_loss:0.0002 valid_loss:0.0002
# 100%|██████████| 300/300 [04:52<00:00,  1.03it/s]

# %%
c620.test(e=0.01)
# Out:
#                                                           R2  ...        MAPE
# Tatoray Stripper C620 Split Factors Calculation...         0  ...   0.0106982
# Tatoray Stripper C620 Split Factors Calculation...  0.998374  ...   0.0152045
# Tatoray Stripper C620 Split Factors Calculation...  0.999003  ...   0.0600455
# Tatoray Stripper C620 Split Factors Calculation...  0.999264  ...    0.158082
# Tatoray Stripper C620 Split Factors Calculation...  0.999119  ...    0.422179
# ...                                                      ...  ...         ...
# Tatoray Stripper C620 Operation_Heat Duty_Conde...  0.999187  ...    0.180544
# Tatoray Stripper C620 Operation_Heat Duty_Reboi...  0.998939  ...    0.227537
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999612  ...  0.00932776
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999651  ...  0.00665903
# AVG                                                 0.791153  ...    0.611087
#
# [174 rows x 3 columns]

# %%
from autorch.function import sp2wt

x_test = c620.data['X_test']
x41 = x_test[c['x41']].values
sp = c620.predict(x_test).iloc[:,:41*4]
s1,s2,s3,s4 = sp.iloc[:,:41].values,sp.iloc[:,41:41*2].values,sp.iloc[:,41*2:41*3].values,sp.iloc[:,41*3:41*4].values
w1,w2,w3,w4 = sp2wt(x41,s1),sp2wt(x41,s2),sp2wt(x41,s3),sp2wt(x41,s4)
wt_pred = np.hstack((w1,w2,w3,w4))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=wt_col)
wt_pred.head(3)
# Out:
#          Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 101-076                                                0.0                                      ...                                                0.0
# 041-048                                                0.0                                      ...                                                0.0
# 007-054                                                0.0                                      ...                                                0.0
#
# [3 rows x 164 columns]

# %%
wt_real = c620_df.loc[x_test.index,wt_col]
wt_real.head(3)
# Out:
#          Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 101-076                                                0.0                                      ...                                                0.0
# 041-048                                                0.0                                      ...                                                0.0
# 007-054                                                0.0                                      ...                                                0.0
#
# [3 rows x 164 columns]

# %%
c620.show_metrics(wt_real,wt_pred,e=0.01).fillna(0)
# Out:
#                                                           R2  ...      MAPE
# Tatoray Stripper C620 Operation_Vent Gas Produc...  1.000000  ...  0.000000
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.999324  ...  0.140258
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.999268  ...  0.100721
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.997673  ...  0.059788
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.999130  ...  0.295090
# ...                                                      ...  ...       ...
# Tatoray Stripper C620 Operation_Bottoms Product...  0.999996  ...  0.019298
# Tatoray Stripper C620 Operation_Bottoms Product...  0.999996  ...  0.019298
# Tatoray Stripper C620 Operation_Bottoms Product...  1.000000  ...  0.000000
# Tatoray Stripper C620 Operation_Bottoms Product...  1.000000  ...  0.000000
# AVG                                                 0.949022  ...  0.968382
#
# [165 rows x 3 columns]

# %%
c620.shrink() # 節省空間

# %%
joblib.dump(c620,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620.pkl']
