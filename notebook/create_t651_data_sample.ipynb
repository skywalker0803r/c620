# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/create_t651_data_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
t651_df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/c620/cleaned/t651_train.csv',index_col=0)

# %%
import joblib
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/t651_col_names.pkl')
c.keys()
# Out:
# dict_keys(['x41', 'MFR'])

# %%
data = t651_df[c['x41']].loc[['001-002', '001-005', '001-008', '001-011', '001-014']]
data
# Out:
#          Extract Feed from T651_Detailed Composition_Hydrogen_wt%  ...  Extract Feed from T651_Detailed Composition_Oxygen_wt%
# 001-002                                                0.0         ...                                                0.0
# 001-005                                                0.0         ...                                                0.0
# 001-008                                                0.0         ...                                                0.0
# 001-011                                                0.0         ...                                                0.0
# 001-014                                                0.0         ...                                                0.0
#
# [5 rows x 41 columns]

# %%
data.to_excel('/content/drive/MyDrive/台塑輕油案子/data/c620/Data_format_example/t651_data.xlsx')
