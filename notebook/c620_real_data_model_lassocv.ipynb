# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/c620_real_data_model_lassocv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # data

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c620_col_names.pkl')
c620_df = pd.read_excel('/content/drive/MyDrive/台塑輕油案子/data/c620/明志_遷移式學習_訓練資料_寄送版/c620_data.xlsx',index_col=0)
c620_df['Tatoray Stripper C620 Operation_Distillate Production Rate and Composition_Hydrogen_wt%'] = 0
print(c620_df.shape)
c620_df.head(3)
# Out:
# (168, 382)
#             Tatoray Stripper C620 Operation_Specifications_Spec 1 : Receiver Temp_oC  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 2020-09-02                                          40.670785                         ...                                                  0
# 2020-09-03                                          40.668301                         ...                                                  0
# 2020-09-04                                          40.720125                         ...                                                  0
#
# [3 rows x 382 columns]

# %% [markdown]
# # X,Y

# %%
x_col = c['case']+c['x41']
wt_col = c['vent_gas_x']+c['distillate_x']+c['sidedraw_x']+c['bottoms_x']
op_col = c['density']+c['yRefluxRate']+c['yHeatDuty']+c['yControl']
print(len(op_col))
op_col = c620_df[op_col].dropna(axis=1).columns.tolist()
print(len(op_col))
y_col = wt_col+op_col
X = c620_df[x_col]
Y = c620_df[y_col]
# Out:
# 10
# 8

# %%
joblib.dump(op_col,'/content/drive/MyDrive/台塑輕油案子/data/c620/map_dict/c620_simple_op_col.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/map_dict/c620_simple_op_col.pkl']

# %% [markdown]
# # train

# %%
from sklearn.linear_model import MultiTaskLassoCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import r2_score,mean_squared_error
from tqdm import tqdm_notebook as tqdm

def mape(y_true, y_pred, e = 1e-8):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true > e
    y_true, y_pred = y_true[mask], y_pred[mask]
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def show_metrics(y_real,y_pred,e=1e-8):
    res = pd.DataFrame(index=y_pred.columns,columns=['R2','MSE','MAPE'])
    for i in y_pred.columns:
        res.loc[i,'R2'] = np.clip(r2_score(y_real[i],y_pred[i]),0,1)
        res.loc[i,'MSE'] = mean_squared_error(y_real[i],y_pred[i])
        res.loc[i,'MAPE'] = mape(y_real[i],y_pred[i],e)
    res.loc['AVG'] = res.mean(axis=0)
    return res

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.1,random_state=0)
model = Pipeline([('scaler', StandardScaler()),('lasso', MultiTaskLassoCV(alphas=[2 for _ in range(len(y_col))]))]).fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred = pd.DataFrame(y_pred,index=X_test.index,columns=y_col)
y_real = pd.DataFrame(y_test,index=X_test.index,columns=y_col)
show_metrics(y_real,y_pred,e=0.02).loc['AVG','MAPE']
# Out:
# 12.39315222568568

# %%
show_metrics(y_real,y_pred,e=0.02)
# Out:
#                                                           R2  ...       MAPE
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.895949  ...     18.383
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.337574  ...    9.28636
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.461017  ...    5.83479
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.773766  ...    4.51007
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.333556  ...    6.57508
# ...                                                      ...  ...        ...
# Density_Bottoms Production Rate and Composition     0.652382  ...  0.0530581
# Tatoray Stripper C620 Operation_Yield Summary_R...  0.258138  ...    3.80095
# Tatoray Stripper C620 Operation_Column Temp Pro...         0  ...    1.40105
# Tatoray Stripper C620 Operation_Column Temp Pro...         0  ...   0.406796
# AVG                                                 0.532223  ...    12.3932
#
# [173 rows x 3 columns]

# %%
y_pred.head(3)
# Out:
#             Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Column Temp Profile_C620 Tray 34 (Control)_oC
# 2021-02-05                                           9.232563                                      ...                                         181.397694
# 2020-10-29                                           8.728971                                      ...                                         181.256714
# 2021-01-07                                           8.440508                                      ...                                         181.272408
#
# [3 rows x 172 columns]

# %%
y_real.head(3)
# Out:
#             Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Column Temp Profile_C620 Tray 34 (Control)_oC
# 2021-02-05                                             3.6305                                      ...                                         180.808533
# 2020-10-29                                             8.8786                                      ...                                         181.876257
# 2021-01-07                                             8.5090                                      ...                                         181.164581
#
# [3 rows x 172 columns]

# %% [markdown]
# # wt

# %%
wt_pred = y_pred[wt_col]
wt_real = y_real[wt_col]
show_metrics(wt_real,wt_pred,e=0.02)
# Out:
#                                                           R2  ...     MAPE
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.895949  ...   18.383
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.337574  ...  9.28636
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.461017  ...  5.83479
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.773766  ...  4.51007
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.333556  ...  6.57508
# ...                                                      ...  ...      ...
# Tatoray Stripper C620 Operation_Bottoms Product...  0.465095  ...  18.0194
# Tatoray Stripper C620 Operation_Bottoms Product...  0.465095  ...  18.0194
# Tatoray Stripper C620 Operation_Bottoms Product...         1  ...      NaN
# Tatoray Stripper C620 Operation_Bottoms Product...         1  ...      NaN
# AVG                                                 0.545422  ...  14.1825
#
# [165 rows x 3 columns]

# %% [markdown]
# # op

# %%
op_pred = y_pred[op_col]
op_real = y_real[op_col]
show_metrics(op_real,op_pred,e=0.02)
# Out:
#                                                            R2  ...         MAPE
# Density_Feed Properties                              0.626955  ...    0.0719084
# Density_Vent Gas Production Rate and Composition            0  ...  2.45082e-14
# Density_Distillate Production Rate and Composition   0.472336  ...     0.328607
# Density_Sidedraw Production Rate and Composition    0.0833655  ...       0.0357
# Density_Bottoms Production Rate and Composition      0.652382  ...    0.0530581
# Tatoray Stripper C620 Operation_Yield Summary_R...   0.258138  ...      3.80095
# Tatoray Stripper C620 Operation_Column Temp Pro...          0  ...      1.40105
# Tatoray Stripper C620 Operation_Column Temp Pro...          0  ...     0.406796
# AVG                                                  0.261647  ...     0.762259
#
# [9 rows x 3 columns]

# %%
#import joblib
#joblib.dump(model,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620_real_data_lassocv.pkl')

# %%
x_col.index('Tatoray Stripper C620 Operation_Specifications_Spec 2 : Distillate Rate_m3/hr')
# Out:
# 1

# %%
y_col.index('Tatoray Stripper C620 Operation_Sidedraw Production Rate and Composition_Benzene_wt%')
# Out:
# 89

# %%
model['lasso'].coef_.shape
# Out:
# (172, 44)

# %%
model['lasso'].coef_[89,1]
# Out:
# 0.0
