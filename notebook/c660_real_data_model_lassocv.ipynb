# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/c660_real_data_model_lassocv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # data

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c660_col_names.pkl')
c660_df = pd.read_excel('/content/drive/MyDrive/台塑輕油案子/data/c620/明志_遷移式學習_訓練資料_寄送版/c660_data.xlsx',index_col=0)
print(c660_df.shape)
c660_df.head(3)
# Out:
# (168, 381)
#             Benzene Column C660 Operation_Specifications_Spec 2 : NA in Benzene_ppmw  ...  Benzene Column C660 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 2020-09-02                                              763.0                         ...                                                  0
# 2020-09-03                                              816.0                         ...                                                  0
# 2020-09-04                                              736.0                         ...                                                  0
#
# [3 rows x 381 columns]

# %% [markdown]
# # X,Y

# %%
x_col = c['case']+c['x41']
wt_col = c['vent_gas_x']+c['distillate_x']+c['sidedraw_x']+c['bottoms_x']
op_col = c['density']+c['yRefluxRate']+c['yHeatDuty']+c['yControl']
print(len(op_col))
op_col = c660_df[op_col].dropna(axis=1).columns.tolist()
print(len(op_col))
y_col = wt_col+op_col
X = c660_df[x_col]
Y = c660_df[y_col]
# Out:
# 10
# 8

# %% [markdown]
# # train

# %%
from sklearn.linear_model import MultiTaskLassoCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import r2_score,mean_squared_error
from tqdm import tqdm_notebook as tqdm

def mape(y_true, y_pred, e = 1e-8):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    mask = y_true > e
    y_true, y_pred = y_true[mask], y_pred[mask]
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def show_metrics(y_real,y_pred,e=1e-8):
    res = pd.DataFrame(index=y_pred.columns,columns=['R2','MSE','MAPE'])
    for i in y_pred.columns:
        res.loc[i,'R2'] = np.clip(r2_score(y_real[i],y_pred[i]),0,1)
        res.loc[i,'MSE'] = mean_squared_error(y_real[i],y_pred[i])
        res.loc[i,'MAPE'] = mape(y_real[i],y_pred[i],e)
    res.loc['AVG'] = res.mean(axis=0)
    return res

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.1,random_state=0)
model = Pipeline([('scaler', StandardScaler()),('lasso', MultiTaskLassoCV())]).fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred = pd.DataFrame(y_pred,index=X_test.index,columns=y_col)
y_real = pd.DataFrame(y_test,index=X_test.index,columns=y_col)
show_metrics(y_real,y_pred,e=0.02).loc['AVG','MAPE']
# Out:
# 20.730931365914074

# %%
show_metrics(y_real,y_pred,e=0.02)
# Out:
#                                                           R2  ...         MAPE
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...          NaN
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...            0
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...            0
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...            0
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...            0
# ...                                                      ...  ...          ...
# Density_Bottoms Production Rate and Composition            0  ...  2.55165e-14
# Benzene Column C660 Operation_Yield Summary_Ref...  0.467325  ...      4.36537
# Benzene Column C660 Operation_Column Temp Profi...  0.545998  ...     0.514669
# Benzene Column C660 Operation_Column Temp Profi...  0.718889  ...     0.558928
# AVG                                                 0.666005  ...      20.7309
#
# [173 rows x 3 columns]

# %%
y_pred.head(3)
# Out:
#             Benzene Column C660 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Benzene Column C660 Operation_Column Temp Profile_C660 Tray 23 (Control)_oC
# 2021-02-05                                                0.0                                    ...                                          90.350935
# 2020-10-29                                                0.0                                    ...                                          90.537446
# 2021-01-07                                                0.0                                    ...                                          91.476303
#
# [3 rows x 172 columns]

# %%
y_real.head(3)
# Out:
#             Benzene Column C660 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Benzene Column C660 Operation_Column Temp Profile_C660 Tray 23 (Control)_oC
# 2021-02-05                                                  0                                    ...                                          91.375000
# 2020-10-29                                                  0                                    ...                                          91.135836
# 2021-01-07                                                  0                                    ...                                          91.741379
#
# [3 rows x 172 columns]

# %% [markdown]
# # wt

# %%
wt_pred = y_pred[wt_col]
wt_real = y_real[wt_col]
show_metrics(wt_real,wt_pred,e=0.02)
# Out:
#                                                           R2  ...     MAPE
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...      NaN
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...        0
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...        0
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...        0
# Benzene Column C660 Operation_Vent Gas Producti...         1  ...        0
# ...                                                      ...  ...      ...
# Benzene Column C660 Operation_Bottoms Productio...         1  ...      NaN
# Benzene Column C660 Operation_Bottoms Productio...         1  ...      NaN
# Benzene Column C660 Operation_Bottoms Productio...         1  ...      NaN
# Benzene Column C660 Operation_Bottoms Productio...         1  ...      NaN
# AVG                                                 0.683198  ...  25.4484
#
# [165 rows x 3 columns]

# %% [markdown]
# # op

# %%
op_pred = y_pred[op_col]
op_real = y_real[op_col]
show_metrics(op_real,op_pred,e=0.02)
# Out:
#                                                           R2  ...         MAPE
# Density_Feed Properties                             0.776124  ...    0.0129987
# Density_Vent Gas Production Rate and Composition           0  ...  1.95118e-14
# Density_Distillate (Benzene Drag) Production Ra...         0  ...  2.59398e-14
# Density_Sidedraw (Benzene )Production Rate and ...         0  ...  1.25449e-14
# Density_Bottoms Production Rate and Composition            0  ...  2.55165e-14
# Benzene Column C660 Operation_Yield Summary_Ref...  0.467325  ...      4.36537
# Benzene Column C660 Operation_Column Temp Profi...  0.545998  ...     0.514669
# Benzene Column C660 Operation_Column Temp Profi...  0.718889  ...     0.558928
# AVG                                                 0.313542  ...     0.681496
#
# [9 rows x 3 columns]

# %%
import joblib
joblib.dump(model,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c660_real_data_lassocv.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/model/c660_real_data_lassocv.pkl']
