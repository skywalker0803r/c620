# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/Modeling_C670.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
from google.colab import drive
drive.mount('/content/drive')
# !pip install autorch > log.txt
import autorch
import torch
torch.manual_seed(11)
import torch
from torch import nn
from torch.optim import Adam
pd.options.display.max_rows = 999
# Out:
# Mounted at /content/drive

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c670_col_names.pkl')
c.keys()
# Out:
# dict_keys(['xTray43', 'xTray54', 'combined', 'upper_bf', 'lower_bf', 'yRefluxRate', 'yControl', 'yHeatDuty', 'distillate_x', 'bottoms_x', 'distillate_sf', 'bottoms_sf', 'density'])

# %%
c670_df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/c620/cleaned/c670_train.csv',index_col=0).dropna(axis=0)
c670_df.head(3)
# Out:
#          Combined Feed to Toluene Column C670 @ Tray 43_Flow Rate_Volume Flow Rate_m3/hr  ...  Density_Bottoms Production Rate and Composition
# 001-001                                          20.862091                                ...                                         0.872382
# 001-002                                          20.862698                                ...                                         0.872382
# 001-003                                          20.863127                                ...                                         0.872382
#
# [3 rows x 424 columns]

# %% [markdown]
# # 欄位定義

# %% [markdown]
# 由於 upper + lower 一定等於 1 所以知道upper就可以知道lower

# %%
np.allclose(c670_df[c['upper_bf']].values+c670_df[c['lower_bf']].values,1.0)
# Out:
# True

# %%
# 根據條件修改值
a = c670_df[c['upper_bf']+c['lower_bf']]
紫色零點零欄位 = a[a==0.0].dropna(axis=1).columns.tolist()
紫色零點一欄位 = a[a==0.1].dropna(axis=1).columns.tolist()
紫色零點九欄位 = a[a==0.9].dropna(axis=1).columns.tolist()
紫色一點零欄位 = a[a==1.0].dropna(axis=1).columns.tolist()
print('修改欄位數量:',len(紫色零點零欄位+紫色零點一欄位+紫色零點九欄位+紫色一點零欄位))
c670_df.loc[:,紫色零點零欄位] = 0.0001 
c670_df.loc[:,紫色零點一欄位] = 0.0001 
c670_df.loc[:,紫色零點九欄位] = 0.9999
c670_df.loc[:,紫色一點零欄位] = 0.9999
c670_df[紫色零點零欄位+紫色零點一欄位+紫色零點九欄位+紫色一點零欄位].head()

# 確認質量平衡
print(np.allclose(c670_df[c['upper_bf']].values+c670_df[c['lower_bf']].values,1.0))
# Out:
# 修改欄位數量: 24
# True

# %%
x_col = c['combined'] + c['upper_bf']# + c['lower_bf']
s_col = c['distillate_sf']+c['bottoms_sf']
wt_col = c['distillate_x']+c['bottoms_x']
op_col = c['density']+c['yRefluxRate']+c['yHeatDuty']+c['yControl']
y_col = s_col + op_col
len(x_col),len(y_col)
# Out:
# (82, 89)

# %%
c670_df.loc[['001-002', '001-005', '001-008', '001-011', '001-014'],
            x_col+y_col].to_excel('/content/drive/MyDrive/台塑輕油案子/data/c620/Data_format_example/c670_data.xlsx')

# %%
n_idx = [[i,i+41] for i in range(41)]
for idx in n_idx:
  assert np.allclose(c670_df[y_col].iloc[:,idx].sum(axis=1).mean(),1.0)

# %% [markdown]
# # train

# %%
from autorch.utils import PartBulider
from torch import nn
from torch.optim import Adam

c670 = PartBulider(c670_df,x_col,y_col,normalize_idx_list=n_idx,limit_y_range=True)
c670.net = nn.Sequential(nn.Linear(len(x_col),64),nn.Linear(64,64),nn.Linear(64,len(y_col)),nn.Sigmoid())
c670.optimizer = Adam(c670.net.parameters())
c670.train()
# Out:
#   0%|          | 1/300 [00:00<03:07,  1.60it/s]
# epoch:0 train_loss:0.0107 valid_loss:0.0038
#  17%|█▋        | 51/300 [00:16<01:17,  3.22it/s]
# epoch:50 train_loss:0.0023 valid_loss:0.0022
#  34%|███▎      | 101/300 [00:31<01:00,  3.28it/s]
# epoch:100 train_loss:0.0022 valid_loss:0.0022
#  50%|█████     | 151/300 [00:47<00:45,  3.25it/s]
# epoch:150 train_loss:0.0022 valid_loss:0.0022
#  67%|██████▋   | 201/300 [01:02<00:32,  3.03it/s]
# epoch:200 train_loss:0.0022 valid_loss:0.0022
#  84%|████████▎ | 251/300 [01:17<00:14,  3.29it/s]
# epoch:250 train_loss:0.0022 valid_loss:0.0022
# 100%|██████████| 300/300 [01:32<00:00,  3.23it/s]

# %%
res = c670.test(e=0.02).loc[op_col,:]
res.loc['AVG'] = res.mean(axis=0)
res
# Out:
#                                                           R2  ...         MAPE
# Density_Distillate Production Rate and Composition  0.992193  ...  0.000225925
# Density_Bottoms Production Rate and Composition      0.99551  ...   0.00254302
# Toluene Column C670 Operation_Yield \nSummary_R...  0.988227  ...     0.749567
# Toluene Column C670 Operation_Heat Duty_Condens...   0.98933  ...     0.733241
# Toluene Column C670 Operation_Heat Duty_Reboile...  0.988675  ...     0.734813
# Toluene Column C670 Operation_Column Temp Profi...   0.97414  ...    0.0175718
# Toluene Column C670 Operation_Column Temp Profi...  0.991621  ...    0.0513903
# AVG                                                 0.988528  ...      0.32705
#
# [8 rows x 3 columns]

# %% [markdown]
# # wt預測結果

# %%
from autorch.function import sp2wt

x_test = c670.data['X_test']
x41 = x_test[c['combined']].values
sp = c670.predict(x_test).iloc[:,:41*2]
s1,s2 = sp.iloc[:,:41].values,sp.iloc[:,41:41*2].values
w1,w2 = sp2wt(x41,s1),sp2wt(x41,s2)
wt_pred = np.hstack((w1,w2))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=wt_col)
wt_pred.head(3)
# Out:
#          Toluene Column C670 Operation_Distillate Production Rate and Composition_Hydrogen_wt%  ...  Toluene Column C670 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 120-051                                                0.0                                      ...                                                0.0
# 050-096                                                0.0                                      ...                                                0.0
# 035-100                                                0.0                                      ...                                                0.0
#
# [3 rows x 82 columns]

# %%
wt_real = c670_df.loc[x_test.index,wt_col]
wt_real.head(3)
# Out:
#          Toluene Column C670 Operation_Distillate Production Rate and Composition_Hydrogen_wt%  ...  Toluene Column C670 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 120-051                                                0.0                                      ...                                                0.0
# 050-096                                                0.0                                      ...                                                0.0
# 035-100                                                0.0                                      ...                                                0.0
#
# [3 rows x 82 columns]

# %%
res = c670.show_metrics(wt_real,wt_pred,e=0.02).fillna(0)
res
# Out:
#                                                           R2  ...      MAPE
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000358
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000423
# Toluene Column C670 Operation_Distillate Produc...  0.999925  ...  0.000371
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.001685
# Toluene Column C670 Operation_Distillate Produc...  0.997115  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.993813  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.988901  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.988832  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.988638  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.985292  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.994958  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.994286  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.988079  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.995032  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.988458  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.987990  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.989373  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.989036  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.993774  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.987914  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.996510  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.995324  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.999376  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.997300  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.996389  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  0.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Distillate Produc...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.991502  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.994459  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.993086  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.989354  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.000000  ...  1.595949
# Toluene Column C670 Operation_Bottoms Productio...  0.976043  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.999917  ...  0.268213
# Toluene Column C670 Operation_Bottoms Productio...  0.999996  ...  0.050872
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.002919
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000584
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000505
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000477
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000483
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000385
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000474
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000385
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000475
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000430
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000477
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000476
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  0.999988  ...  0.018589
# Toluene Column C670 Operation_Bottoms Productio...  0.999999  ...  0.018564
# Toluene Column C670 Operation_Bottoms Productio...  0.999999  ...  0.018725
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# Toluene Column C670 Operation_Bottoms Productio...  1.000000  ...  0.000000
# AVG                                                 0.911959  ...  0.070881
#
# [83 rows x 3 columns]

# %%
c670.shrink()

# %%
joblib.dump(c670,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c670.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/model/c670.pkl']
