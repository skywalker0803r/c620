# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/c620/blob/main/notebook/experiment/Experimental_separation_coefficient_post-processing_and_model_disassembly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
# !pip install autorch > log.txt

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c620_col_names.pkl')
c620_df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/c620/cleaned/c620_train.csv',index_col=0).dropna(axis=0)
print(c620_df.shape)
c620_df.head(3)
# Out:
# (15552, 420)
#          Combined Feed to Tatoray Stripper C620_Flow Rate_Volume Flow Rate_m3/hr  ...  Density_Bottoms Production Rate and Composition
# 001-001                                              178.0                        ...                                         0.871859
# 001-002                                              178.0                        ...                                         0.871859
# 001-003                                              178.0                        ...                                         0.871859
#
# [3 rows x 420 columns]

# %%
x_col = c['case']+c['x41']
op_col = c['density']+c['yRefluxRate']+c['yHeatDuty']+c['yControl']
sp_col = c['vent_gas_sf'] +c['distillate_sf'] +c['sidedraw_sf'] +c['bottoms_sf']
wt_col = c['vent_gas_x'] +c['distillate_x'] +c['sidedraw_x'] +c['bottoms_x']
y_col = sp_col + op_col
n_idx = [ [i,i+41,i+41*2,i+41*3]for i in range(41)]
for idx in n_idx:
  assert np.allclose(c620_df[y_col].iloc[:,idx].sum(axis=1),1.0) # check
print(len(x_col),len(y_col))
# Out:
# 44 174

# %%
#c620_df.loc[['001-002', '001-005', '001-008', '001-011', '001-014'],
#            x_col+y_col].to_excel('/content/drive/MyDrive/台塑輕油案子/data/c620/Data_format_example/c620_data.xlsx')

# %%
from autorch.utils import PartBulider
c620 = PartBulider(c620_df,x_col,y_col)
c620.train()
# Out:
#   0%|          | 1/300 [00:00<02:36,  1.91it/s]
# epoch:0 train_loss:0.9537 valid_loss:0.0660
#  17%|█▋        | 51/300 [00:39<03:15,  1.27it/s]
# epoch:50 train_loss:0.0013 valid_loss:0.0009
#  34%|███▎      | 101/300 [01:19<02:40,  1.24it/s]
# epoch:100 train_loss:0.0008 valid_loss:0.0008
#  50%|█████     | 151/300 [01:59<01:57,  1.26it/s]
# epoch:150 train_loss:0.0005 valid_loss:0.0003
#  67%|██████▋   | 201/300 [02:38<01:17,  1.27it/s]
# epoch:200 train_loss:0.0005 valid_loss:0.0011
#  84%|████████▎ | 251/300 [03:19<00:41,  1.19it/s]
# epoch:250 train_loss:0.0006 valid_loss:0.0003
# 100%|██████████| 300/300 [04:06<00:00,  1.22it/s]

# %%
c620.test(e=0.01)
# Out:
#                                                           R2  ...        MAPE
# Tatoray Stripper C620 Split Factors Calculation...         0  ...     2.37668
# Tatoray Stripper C620 Split Factors Calculation...  0.517808  ...    0.265668
# Tatoray Stripper C620 Split Factors Calculation...  0.505206  ...     1.60423
# Tatoray Stripper C620 Split Factors Calculation...  0.990509  ...    0.542435
# Tatoray Stripper C620 Split Factors Calculation...    0.9943  ...     1.02271
# ...                                                      ...  ...         ...
# Tatoray Stripper C620 Operation_Heat Duty_Conde...  0.999941  ...   0.0492253
# Tatoray Stripper C620 Operation_Heat Duty_Reboi...  0.999872  ...   0.0786055
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999518  ...   0.0102574
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999413  ...  0.00956348
# AVG                                                 0.169085  ...     11.9491
#
# [175 rows x 3 columns]

# %% [markdown]
# # 分離係數原始預測 不能滿足化工約束條件

# %%
sp = c620.predict(c620.data['X_test']).filter(regex='Split Factor')
for i in range(41):
  assert np.allclose(sp.iloc[:,[i,i+41,i+41*2,i+41*3]].sum(axis=1).values,1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-28-d93a08682d77> in <module>()
#       1 sp = c620.predict(c620.data['X_test']).filter(regex='Split Factor')
#       2 for i in range(41):
# ----> 3   assert np.allclose(sp.iloc[:,[i,i+41,i+41*2,i+41*3]].sum(axis=1).values,1)
#
# AssertionError:

# %% [markdown]
# # 因此做分離係數後處理

# %%
sp = c620.predict(c620.data['X_test']).filter(regex='Split Factor').clip(0,1)
for i in range(41):
  total_sum = sp.iloc[:,[i,i+41,i+41*2,i+41*3]].sum(axis=1).values.reshape(-1,1)
  sp.iloc[:,[i,i+41,i+41*2,i+41*3]] = sp.iloc[:,[i,i+41,i+41*2,i+41*3]]/total_sum

# %% [markdown]
# # 確保分離係數後處理沒問題

# %%
for i in range(41):
  assert np.allclose(sp.iloc[:,[i,i+41,i+41*2,i+41*3]].sum(axis=1).values,1)

# %% [markdown]
# # 再次測試預測表現

# %%
y_real = c620.data['Y_test']
y_pred = c620.predict(c620.data['X_test'])
y_pred.update(sp)
c620.show_metrics(y_real,y_pred)
# Out:
#                                                           R2  ...         MAPE
# Tatoray Stripper C620 Split Factors Calculation...         0  ...      0.15891
# Tatoray Stripper C620 Split Factors Calculation...         0  ...     0.488904
# Tatoray Stripper C620 Split Factors Calculation...  0.967671  ...      0.32902
# Tatoray Stripper C620 Split Factors Calculation...  0.961254  ...      1.13221
# Tatoray Stripper C620 Split Factors Calculation...  0.983552  ...      1.87143
# ...                                                      ...  ...          ...
# Tatoray Stripper C620 Operation_Heat Duty_Conde...  0.999941  ...    0.0492253
# Tatoray Stripper C620 Operation_Heat Duty_Reboi...  0.999872  ...    0.0786055
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999518  ...    0.0102574
# Tatoray Stripper C620 Operation_Column Temp Pro...  0.999413  ...   0.00956348
# AVG                                                 0.194467  ...  2.05741e+06
#
# [175 rows x 3 columns]

# %%
from autorch.function import sp2wt

x_test = c620.data['X_test']
x41 = x_test[c['x41']].values
#sp = c620.predict(x_test).iloc[:,:41*4]
s1,s2,s3,s4 = sp.iloc[:,:41].values,sp.iloc[:,41:41*2].values,sp.iloc[:,41*2:41*3].values,sp.iloc[:,41*3:41*4].values
w1,w2,w3,w4 = sp2wt(x41,s1),sp2wt(x41,s2),sp2wt(x41,s3),sp2wt(x41,s4)
wt_pred = np.hstack((w1,w2,w3,w4))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=wt_col)
wt_pred.head(3)
# Out:
#          Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 121-038                                                0.0                                      ...                                                0.0
# 018-066                                                0.0                                      ...                                                0.0
# 002-026                                                0.0                                      ...                                                0.0
#
# [3 rows x 164 columns]

# %%
wt_real = c620_df.loc[x_test.index,wt_col]
wt_real.head(3)
# Out:
#          Tatoray Stripper C620 Operation_Vent Gas Production Rate and Composition_Hydrogen_wt%  ...  Tatoray Stripper C620 Operation_Bottoms Production Rate and Composition_Oxygen_wt%
# 121-038                                                0.0                                      ...                                                0.0
# 018-066                                                0.0                                      ...                                                0.0
# 002-026                                                0.0                                      ...                                                0.0
#
# [3 rows x 164 columns]

# %%
c620.show_metrics(wt_real,wt_pred,e=0.01).fillna(0)
# Out:
#                                                           R2  ...       MAPE
# Tatoray Stripper C620 Operation_Vent Gas Produc...  1.000000  ...   0.000000
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.000000  ...  15.180270
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.000000  ...  15.391436
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.000000  ...  14.667933
# Tatoray Stripper C620 Operation_Vent Gas Produc...  0.000000  ...  14.126782
# ...                                                      ...  ...        ...
# Tatoray Stripper C620 Operation_Bottoms Product...  0.995318  ...   0.958688
# Tatoray Stripper C620 Operation_Bottoms Product...  0.992152  ...   1.136249
# Tatoray Stripper C620 Operation_Bottoms Product...  1.000000  ...   0.000000
# Tatoray Stripper C620 Operation_Bottoms Product...  1.000000  ...   0.000000
# AVG                                                 0.353498  ...  80.003408
#
# [165 rows x 3 columns]

# %%
c620.shrink() # 節省空間

# %%
#joblib.dump(c620,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/model/c620.pkl']
