# %%
import pandas as pd
import numpy as np
import joblib
#!pip install autorch

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/c620/col_names/c660_col_names.pkl')
c.keys()
# Out:
# dict_keys(['x41', 'case', 'yRefluxRate', 'yControl', 'yHeatDuty', 'vent_gas_x', 'distillate_x', 'sidedraw_x', 'bottoms_x', 'vent_gas_sf', 'distillate_sf', 'sidedraw_sf', 'bottoms_sf', 'density'])

# %%
c660_df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/c620/cleaned/c660_train.csv',index_col=0).dropna(axis=0)
print(c660_df.shape)
c660_df.head()
# Out:
# (15552, 380)
#          Combined Feed to Benzene Column C660_Detailed Composition_Hydrogen_wt%  ...  Benzene Column C660 Split Factors Calculation_Split Factor for Individual Component to Benzene Column C660 Bottoms_Oxygen_Fraction
# 001-001                                                0.0                       ...                                                0.0
# 001-002                                                0.0                       ...                                                0.0
# 001-003                                                0.0                       ...                                                0.0
# 001-004                                                0.0                       ...                                                0.0
# 001-005                                                0.0                       ...                                                0.0
#
# [5 rows x 380 columns]

# %%
for k,v in c.items():
  print(k,len(v))
# Out:
# x41 41
# case 2
# yRefluxRate 1
# yControl 2
# yHeatDuty 2
# vent_gas_x 41
# distillate_x 41
# sidedraw_x 41
# bottoms_x 41
# vent_gas_sf 41
# distillate_sf 41
# sidedraw_sf 41
# bottoms_sf 41
# density 4

# %%
x_col = c['case']+c['x41']
op_col = c['yRefluxRate']+c['yControl']+c['yHeatDuty']+c['density']
sp_col = c['vent_gas_sf'] +c['distillate_sf'] +c['sidedraw_sf'] +c['bottoms_sf']
wt_col = c['vent_gas_x'] +c['distillate_x'] +c['sidedraw_x'] +c['bottoms_x']
y_col = sp_col + op_col
n_idx = [ [i,i+41,i+41*2,i+41*3]for i in range(41)]
for idx in n_idx:
  assert np.allclose(c660_df[y_col].iloc[:,idx].sum(axis=1).mean(),1.0)

# %%
from autorch.utils import PartBulider
c660 = PartBulider(c660_df,x_col,y_col,normalize_idx_list=n_idx)
c660.train()
c660.test()
# Out:
#   0%|          | 1/300 [00:00<04:47,  1.04it/s]
# epoch:0 train_loss:0.0086 valid_loss:0.0021
#  17%|█▋        | 51/300 [00:50<04:11,  1.01s/it]
# epoch:50 train_loss:0.0009 valid_loss:0.0009
#  34%|███▎      | 101/300 [01:39<03:14,  1.02it/s]
# epoch:100 train_loss:0.0008 valid_loss:0.0009
#  50%|█████     | 151/300 [02:29<02:27,  1.01it/s]
# epoch:150 train_loss:0.0008 valid_loss:0.0009
#  67%|██████▋   | 201/300 [03:19<01:40,  1.02s/it]
# epoch:200 train_loss:0.0007 valid_loss:0.0009
#  84%|████████▎ | 251/300 [04:12<00:51,  1.06s/it]
# epoch:250 train_loss:0.0007 valid_loss:0.0009
# 100%|██████████| 300/300 [05:13<00:00,  1.04s/it]
#                                                           R2  ...         MAPE
# Benzene Column C660 Split Factors Calculation_S...         0  ...    0.0487837
# Benzene Column C660 Split Factors Calculation_S...  0.990077  ...       1.2922
# Benzene Column C660 Split Factors Calculation_S...   0.99763  ...      2.92202
# Benzene Column C660 Split Factors Calculation_S...  0.999075  ...      3.82648
# Benzene Column C660 Split Factors Calculation_S...  0.998867  ...      5.41876
# ...                                                      ...  ...          ...
# Density_Vent Gas Production Rate and Composition    0.998686  ...     0.092485
# Density_Distillate (Benzene Drag) Production Ra...   0.99811  ...    0.0325724
# Density_Sidedraw (Benzene )Production Rate and ...   0.98763  ...  9.97035e-05
# Density_Bottoms Production Rate and Composition     0.999219  ...  0.000667905
# AVG                                                 0.564999  ...      1.53313
#
# [174 rows x 3 columns]

# %%
c660.shrink()

# %%
joblib.dump(c660,'/content/drive/MyDrive/台塑輕油案子/data/c620/model/c660.pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/data/c620/model/c660.pkl']
